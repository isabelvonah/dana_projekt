# %%
import pandas as pd
import numpy as np
#from pandas_profiling import ProfileReport
#import seaborn as sns
import matplotlib.pyplot as plt

# for Q-Q plots
import scipy.stats as stats
# from feature-engine
# from feature-engine
from feature_engine.imputation import (
    AddMissingIndicator,
    MeanMedianImputer,
    CategoricalImputer,
)

import plotly.express as px
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.figure_factory import create_scatterplotmatrix
from plotly.subplots import make_subplots


# to split the datasets
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Laden der Daten

# %%
X_train = pd.read_csv("Xtrain.csv")
X_test = pd.read_csv("Xtest.csv")
ytrain = pd.read_csv("ytrain.csv")
ytest = pd.read_csv("ytest.csv")
print("Shape of X Train: {}".format(X_train.shape))
print("Shape of X Test: {}".format(X_test.shape))
print("Shape of y Train: {}".format(ytrain.shape))
print("Shape of y Test: {}".format(ytest.shape))
# Out:
# Shape of X Train: (8672, 9)
# Shape of X Test: (2169, 9)
# Shape of y Train: (8672, 1)
# Shape of y Test: (2169, 1)

# %% [markdown]
# # Variablen Übersicht

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8672 entries, 0 to 8671
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        8672 non-null   object
#  1   Rating          8672 non-null   float64
#  2   Reviews         8672 non-null   int64
#  3   Size            8672 non-null   object
#  4   Type            8672 non-null   object
#  5   Price           8672 non-null   object
#  6   Content Rating  8672 non-null   object
#  7   Genres          8672 non-null   object
#  8   Last Updated    8672 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 609.9+ KB

# %% [markdown]
# ## Deskriptive Statistics
# In diesem Abschnitt werden wir Deskriptive Statistiken betrachten. Wegen Zeitgründen und Platzgründen werden wir nicht alle Daten anschauen können. Wir werden hier nur eine Auswahl von mir als interessante eingestufte Variablen Sehen.

# %% [markdown]
# ## Category Variable

# %%
fig_cat = px.histogram(X_train, x="Category")
fig_cat.show()

# %%
fig_cat2 = px.histogram(X_train, x="Category", histnorm = 'probability')
fig_cat2.show()

# %%
print(X_train['Category'].describe())
# Out:
# count       8672
# unique        33
# top       FAMILY
# freq        1583
# Name: Category, dtype: object

# %%
len(X_train['Category'].unique())
# Out:
# 33

# %%
X_train['Category'].value_counts()
# Out:
# FAMILY                 1583
# GAME                    911
# TOOLS                   692
# MEDICAL                 367
# BUSINESS                364
# PRODUCTIVITY            333
# PERSONALIZATION         321
# COMMUNICATION           317
# LIFESTYLE               299
# SPORTS                  289
# HEALTH_AND_FITNESS      278
# FINANCE                 274
# PHOTOGRAPHY             266
# SOCIAL                  231
# NEWS_AND_MAGAZINES      227
# SHOPPING                211
# TRAVEL_AND_LOCAL        209
# DATING                  188
# BOOKS_AND_REFERENCE     177
# EDUCATION               135
# ENTERTAINMENT           134
# VIDEO_PLAYERS           129
# MAPS_AND_NAVIGATION     109
# FOOD_AND_DRINK           97
# AUTO_AND_VEHICLES        79
# LIBRARIES_AND_DEMO       72
# HOUSE_AND_HOME           72
# WEATHER                  61
# EVENTS                   53
# PARENTING                52
# COMICS                   51
# ART_AND_DESIGN           50
# BEAUTY                   41
# ...

# %% [markdown]
# ## Rating Variable

# %%
fig_rat = px.histogram(X_train, x="Rating")
fig_rat.show()

# %%
fig_rat2 = px.histogram(X_train, x="Rating", histnorm = 'probability')
fig_rat2.show()

# %%
print(X_train['Rating'].describe())
# Out:
# count    8672.000000
# mean        4.206192
# std         0.480617
# min         1.000000
# 25%         4.100000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
len(X_train['Rating'].unique())
# Out:
# 38

# %%
X_train['Rating'].value_counts()
# Out:
# 4.3    2021
# 4.4     906
# 4.5     834
# 4.2     769
# 4.6     656
# 4.1     563
# 4.0     452
# 4.7     406
# 3.9     305
# 3.8     238
# 5.0     209
# 3.7     198
# 4.8     185
# 3.6     142
# 3.5     140
# 3.4     100
# 3.3      81
# 4.9      72
# 3.0      64
# 3.1      54
# 3.2      48
# 2.9      32
# 2.8      32
# 2.7      23
# 2.5      20
# 2.6      20
# 2.4      16
# 2.3      14
# 1.0      14
# 2.2      10
# 2.0      10
# 2.1       7
# 1.7       7
# 1.9       7
# 1.8       7
# 1.6       4
# 1.4       3
# 1.5       3
# Name: Rating, dtype: int64

# %% [markdown]
#  ## Reviews Variable

# %%
fig_rat = px.histogram(X_train, x="Reviews")
fig_rat.show()

# %%
fig_rat2 = px.histogram(X_train, x="Reviews", histnorm = 'probability')
fig_rat2.show()

# %%
print(X_train['Reviews'].describe())
# Out:
# count    8.672000e+03
# mean     4.349809e+05
# std      2.879919e+06
# min      0.000000e+00
# 25%      3.800000e+01
# 50%      2.163500e+03
# 75%      5.578025e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
len(X_train['Reviews'].unique())
# Out:
# 4991

# %%
X_train['Reviews'].value_counts()
# Out:
# 0           481
# 1           214
# 2           166
# 3           132
# 4           108
#            ...
# 1225367       1
# 1329008       1
# 10216538      1
# 1443          1
# 2036          1
# Name: Reviews, Length: 4991, dtype: int64

# %%
X_train.to_csv("Xtrain_mod_a.csv",index=False)
X_test.to_csv("Xtest_mod_a.csv",index=False)
